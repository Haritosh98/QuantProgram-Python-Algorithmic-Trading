# %%
# accessing the class made in chapter 8
from smabacktest import SMABacktester

# %% [markdown]
# # 1. Testing if the smabacktest.py file worked

# %%
tester = SMABacktester("SPY", 50, 100, '2000-01-01', '2020-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_result()
# Out:
# (2.592726, 0.297824)

# %%
tester.plot_results()

# %% [markdown]
# # 2. Check other stocks

# %%
tester = SMABacktester("AAPL", 50, 100, '2000-01-01', '2020-01-01')
print(tester.test_result())
tester.plot_results()

# we see that the strategy was very poor
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (7.803987, -85.963095)

# %%
tester = SMABacktester("AAPL", 1, 200, '2000-01-01', '2020-01-01')
print(tester.test_result())
tester.plot_results()

# no the strategy has performed better
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (239.027886, 47.814157)
